# %% [markdown]
# <a href="https://colab.research.google.com/github/divyakanojia/Deeplearning/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
df = pd.DataFrame(data['data'], columns = data["feature_names"])

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df["target"]= data["target"]

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
sns.set_style("darkgrid")
sns.countplot(x = "target", data = df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
df.corr()["target"].sort_values()
# Out:
# worst concave points      -0.793566
# worst perimeter           -0.782914
# mean concave points       -0.776614
# worst radius              -0.776454
# mean perimeter            -0.742636
# worst area                -0.733825
# mean radius               -0.730029
# mean area                 -0.708984
# mean concavity            -0.696360
# worst concavity           -0.659610
# mean compactness          -0.596534
# worst compactness         -0.590998
# radius error              -0.567134
# perimeter error           -0.556141
# area error                -0.548236
# worst texture             -0.456903
# worst smoothness          -0.421465
# worst symmetry            -0.416294
# mean texture              -0.415185
# concave points error      -0.408042
# mean smoothness           -0.358560
# mean symmetry             -0.330499
# worst fractal dimension   -0.323872
# compactness error         -0.292999
# concavity error           -0.253730
# fractal dimension error   -0.077972
# ...

# %%
plt.figure(figsize=(20,12))
df.corr()["target"].sort_values()[:-1].plot(kind = "bar")
# Out:
# <Axes: >

# %%
X = df.drop("target", axis = 1).values
y = df["target"].values
X.shape
# Out:
# (569, 30)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.33)
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense

# %%
X_train.shape
# Out:
# (381, 30)

# %%
model = Sequential()
model.add(Dense(30, activation = "relu")) #Input layer
model.add(Dense(15, activation = "relu"))
model.add(Dense(7, activation = "relu" ))
model.add(Dense(1, activation = "sigmoid"))#output layer
model.compile(loss = "binary_crossentropy", optimizer = "adam")

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(patience = 10)
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(30, activation='relu')) # Input layer
model.add(Dropout(0.5))


model.add(Dense(15, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid')) # Output layer

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(X_train, y_train, epochs = 600, validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/600
# 12/12 [==============================] - 2s 21ms/step - loss: 0.7079 - val_loss: 0.6864
# Epoch 2/600
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6925 - val_loss: 0.6807
# Epoch 3/600
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6936 - val_loss: 0.6761
# Epoch 4/600
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6787 - val_loss: 0.6736
# Epoch 5/600
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6778 - val_loss: 0.6700
# Epoch 6/600
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6702 - val_loss: 0.6652
# Epoch 7/600
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6752 - val_loss: 0.6585
# Epoch 8/600
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6530 - val_loss: 0.6470
# Epoch 9/600
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6647 - val_loss: 0.6310
# Epoch 10/600
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#        loss  val_loss
# 0  0.707880  0.686404
# 1  0.692523  0.680689
# 2  0.693621  0.676107
# 3  0.678668  0.673592
# 4  0.677766  0.670006

# %%
loss_df.plot()
# Out:
# <Axes: >

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5).astype('int32')
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
# 6/6 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        65
#            1       0.96      0.97      0.96       123
#
#     accuracy                           0.95       188
#    macro avg       0.95      0.95      0.95       188
# weighted avg       0.95      0.95      0.95       188

# %%
test = np.random.randint(low=1, high=200, size=(1, 30))
test
# Out:
# array([[149,  46,   7, 182,  89,  56,  62, 175, 136,  99, 148, 136,  45,
#         182,  36,  58, 194, 137,   2,  48,  10, 156,  81, 181,  22,  23,
#          53,  48, 175, 187]])

# %%
test = scaler.transform(test)
model.predict(test)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[1.]], dtype=float32)
